# %%
import nltk
nltk.download('punkt_tab')
Text="India is my Country!"
from nltk.tokenize import word_tokenize
tokenize_word=word_tokenize(Text)
print(tokenize_word)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['India', 'is', 'my', 'Country', '!']

# %%
# Removing stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words("english"))
stop_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
# ...

# %%
Text = " How to remove Stopwords, Punctuations from NLTK library in Python? "
import re
Text = re.sub('[^a-zA-Z]',' ', Text)
Text
# Out:
# ' How to remove Stopwords  Punctuations from NLTK library in Python  '

# %%
# To convert lower text
tokens = word_tokenize(Text.lower())
tokens
# Out:
# ['how',
#  'to',
#  'remove',
#  'stopwords',
#  'punctuations',
#  'from',
#  'nltk',
#  'library',
#  'in',
#  'python']

# %%
# To remove stopwords
filtered_text = [ ]
for w in tokens:
    if w not in stop_words:
        filtered_text.append(w)

print( filtered_text)
# Out:
# ['remove', 'stopwords', 'punctuations', 'nltk', 'library', 'python']

# %%
# Stemming
from nltk.stem import PorterStemmer
ps = PorterStemmer()
words = ["wait","waiting","waited","waits"]
for word in words:
    print(ps.stem(word))
# Out:
# wait
# wait
# wait
# wait

# %%
# Lemmatizer
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
le = WordNetLemmatizer()
for w in nltk.word_tokenize(" Studing Studies"):
    print(w,"->",le.lemmatize(w))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Studing -> Studing
# Studies -> Studies

# %%
# POS
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger_eng')
data = " The children was playing in garden"
words = word_tokenize(data)
print(pos_tag(words))
# Out:
# [('The', 'DT'), ('children', 'NNS'), ('was', 'VBD'), ('playing', 'VBG'), ('in', 'IN'), ('garden', 'NN')]
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
# Term Frequency

documentA = "Jupitor is the largest planet."
documentB =  "Mars is the fourth planet from the Sun"

bagofwordsA=documentA.split()
bagofwordsB=documentB.split()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

uniqueWords=set(bagofwordsA).union(set(bagofwordsB))
uniqueWords
# Out:
# {'Jupitor',
#  'Mars',
#  'Sun',
#  'fourth',
#  'from',
#  'is',
#  'largest',
#  'planet',
#  'planet.',
#  'the'}

# %%
def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict

# %%
tf_documentA = computeTF(wordDictA, bagofwordsA)
tf_documentB = computeTF(wordDictB, bagofwordsB)

print(tf_documentA)
print(tf_documentB)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5473/3257924454.py in <cell line: 0>()
# ----> 1 tf_documentA = computeTF(wordDictA, bagofwordsA)
#       2 tf_documentB = computeTF(wordDictB, bagofwordsB)
#       3
#       4 print(tf_documentA)
#       5 print(tf_documentB)
#
# NameError: name 'wordDictA' is not defined

# %%
def computeIDF(documents):
    import math
    N = len(documents)
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    for words,val in idfDict.items():
      idfDict[word]=math.log(N|float(val))
      return idfDict
# Out:
#   File "/tmp/ipykernel_5473/1790781646.py", line 9
#     for words,val in idfDict.items():
#                                                        ^
# SyntaxError: incomplete input

# %%
# 1. Create the lists of words (Bag of Words)
bagofwordsA = A.replace('.', '').split()
bagofwordsB = B.split()

# 2. Create a unique set of all words from both sentences
uniqueWords = set(bagofwordsA).union(set(bagofwordsB))

# 3. Create dictionaries with 0 counts for all unique words
wordDictA = dict.fromkeys(uniqueWords, 0)
wordDictB = dict.fromkeys(uniqueWords, 0)

# 4. Count the words for Document A
for word in bagofwordsA:
    wordDictA[word] += 1

# 5. Count the words for Document B
for word in bagofwordsB:
    wordDictB[word] += 1

# NOW you can run your function
tf_documentA = computeTF(wordDictA, bagofwordsA)
tf_documentB = computeTF(wordDictB, bagofwordsB)

print(tf_documentA)
# Out:
# {'from': 0.0, 'Jupitor': 0.2, 'fourth': 0.0, 'is': 0.2, 'Mars': 0.0, 'the': 0.2, 'Sun': 0.0, 'planet': 0.2, 'largest': 0.2}

# %%
# TD IDF
def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    return tfidf

# %%
# Calculate TFIDF from A
tfidf_documentA = computeTFIDF(tf_documentA, idfs) - tfidf_documentA
# from B
tfidf_documentB = computeTFIDF(tf_documentB, idfs) - tfidf_documentB
df=pd.DataFrame([tfidf_documentA,tfidf_documentB])
df
